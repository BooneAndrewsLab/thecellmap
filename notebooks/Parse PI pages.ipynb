# %%
from bs4 import BeautifulSoup
from urllib import urlopen

# %%
bs = BeautifulSoup(urlopen('http://live-donnelly-centre.pantheon.io/faculty'), 'html.parser')

# %%
menu = bs.find_all("div", class_="secondary-menu")
for pi in menu[0].find_all('a'):
    print '\t'.join([pi.string, 'http://live-donnelly-centre.pantheon.io' + pi['href'], pi.string + '[Author] OR'])
# Out:
# Andrews, Brenda	http://live-donnelly-centre.pantheon.io/content/brenda-andrews	Andrews, Brenda[Author] OR
# Audet, Julie	http://live-donnelly-centre.pantheon.io/content/julie-audet	Audet, Julie[Author] OR
# Attisano, Liliana	http://live-donnelly-centre.pantheon.io/content/liliana-attisano	Attisano, Liliana[Author] OR
# Bader, Gary	http://live-donnelly-centre.pantheon.io/content/gary-bader	Bader, Gary[Author] OR
# Blencowe, Benjamin	http://live-donnelly-centre.pantheon.io/content/benjamin-blencowe	Blencowe, Benjamin[Author] OR
# Boone, Charles	http://live-donnelly-centre.pantheon.io/content/charles-boone	Boone, Charles[Author] OR
# Brown, Grant	http://live-donnelly-centre.pantheon.io/content/grant-brown	Brown, Grant[Author] OR
# Caudy, Amy	http://live-donnelly-centre.pantheon.io/content/amy-caudy	Caudy, Amy[Author] OR
# Chan, Warren	http://live-donnelly-centre.pantheon.io/content/warren-chan	Chan, Warren[Author] OR
# Emili, Andrew	http://live-donnelly-centre.pantheon.io/content/andrew-emili	Emili, Andrew[Author] OR
# Fraser, Andrew	http://live-donnelly-centre.pantheon.io/content/andrew-fraser	Fraser, Andrew[Author] OR
# Frey, Brendan	http://live-donnelly-centre.pantheon.io/content/brendan-frey	Frey, Brendan[Author] OR
# Gilbert, Penney	http://live-donnelly-centre.pantheon.io/content/penney-gilbert	Gilbert, Penney[Author] OR
# Greenblatt, Jack	http://live-donnelly-centre.pantheon.io/content/jack-greenblatt	Greenblatt, Jack[Author] OR
# Hughes, Timothy	http://live-donnelly-centre.pantheon.io/content/timothy-hughes-0	Hughes, Timothy[Author] OR
# Kim, Philip	http://live-donnelly-centre.pantheon.io/content/philip-kim	Kim, Philip[Author] OR
# Krause, Henry	http://live-donnelly-centre.pantheon.io/content/henry-krause	Krause, Henry[Author] OR
# Moffat, Jason	http://live-donnelly-centre.pantheon.io/content/jason-moffat	Moffat, Jason[Author] OR
# Morris, Quaid	http://live-donnelly-centre.pantheon.io/content/quaid-morris	Morris, Quaid[Author] OR
# Morshead, Cindi	http://live-donnelly-centre.pantheon.io/content/cindi-morshead	Morshead, Cindi[Author] OR
# Rosebrock, Adam	http://live-donnelly-centre.pantheon.io/content/adam-rosebrock	Rosebrock, Adam[Author] OR
# Roth, Frederick (Fritz)	http://live-donnelly-centre.pantheon.io/content/frederick-fritz-roth	Roth, Frederick (Fritz)[Author] OR
# Roy, Peter	http://live-donnelly-centre.pantheon.io/content/peter-roy	Roy, Peter[Author] OR
# Ryu, William	http://live-donnelly-centre.pantheon.io/content/william-ryu	Ryu, William[Author] OR
# Sefton, Michael	http://live-donnelly-centre.pantheon.io/content/michael-sefton	Sefton, Michael[Author] OR
# Shoichet, Molly	http://live-donnelly-centre.pantheon.io/content/molly-shoichet	Shoichet, Molly[Author] OR
# Sidhu, Sachdev	http://live-donnelly-centre.pantheon.io/content/sachdev-sidhu	Sidhu, Sachdev[Author] OR
# Stagljar, Igor	http://live-donnelly-centre.pantheon.io/content/igor-stagljar	Stagljar, Igor[Author] OR
# Taipale, Mikko	http://live-donnelly-centre.pantheon.io/content/mikko-taipale	Taipale, Mikko[Author] OR
# van der Kooy, Derek	http://live-donnelly-centre.pantheon.io/content/derek-van-der-kooy	van der Kooy, Derek[Author] OR
# Wheeler, Aaron	http://live-donnelly-centre.pantheon.io/content/aaron-wheeler	Wheeler, Aaron[Author] OR
# Yip, Christopher	http://live-donnelly-centre.pantheon.io/content/christopher-yip	Yip, Christopher[Author] OR
# Zandstra, Peter	http://live-donnelly-centre.pantheon.io/content/peter-zandstra	Zandstra, Peter[Author] OR
# Zhang, Zhaolei	http://live-donnelly-centre.pantheon.io/content/zhaolei-zhang	Zhang, Zhaolei[Author] OR
