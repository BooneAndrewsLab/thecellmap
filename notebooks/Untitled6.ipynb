# %%
safe = Annotation.objects.all()[4]

# %%
genes = set()

# %%
for term in safe.term_set.prefetch_related('genes', 'strains'):
    print term, genes.update(term.genes.all())
# Out:
# Transcription None
# Cell polarity & morphogenesis None
# Chromatin organization/modification None
# Chaperone-dependent protein folding None
# MVB sorting and pH depending signaling None
# Vesicle traffic None
# mRNA & tRNA processing None
# tRNA wobble modification None
# Peroxisome None
# Metabolism None
# Ribosome biogenesis None
# Nuclear-cytoplasmic transport None
# Protein degradation/turnover None
# Mitosis & chromosome segregation None
# Cytokinesis None
# Respiration, oxidative phosphorylation, mitochondrial targeting None
# Glycosylation, protein folding/targeting, cell wall biosynthesis None
# DNA replication & repair None
# rRNA & ncRNA processing None

# %%
len(genes
   
   
   
   )
# Out:
# 1480
