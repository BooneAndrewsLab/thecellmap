# %%
r = Region.objects.get(pk=670)

# %%
for v in r.vertices.all():
    print(v.label())
# Out:
# RPL41A
# JEM1
# ORM1
# YER053C-A
# CPR2
# VPS64
# ZDS1
# FAR3
# RBH2

# %%
v = Vertex.objects.get(strain__gene__name='RPL8A', region=670)

# %%
strain = Strain.objects.filter(gene__name='HBS1')

# %%
v.strain = strain[0]
v.save()

# %%
1360,1495,2544,6119,3865,4123,5355,5346,6219

# %%
r = Region.objects.get(pk=678)

# %%
r.vertices.clear()
for d, n in enumerate((987,5919,2268,218,5074,2817,4389,3843,5364,5155)):
    Vertex.objects.create(region=r,
                         strain_id=sorted(node2strain[n])[0],
                         degree=d)

# %%
ds = Dataset.objects.all()[1]

# %%
import json
import pickle

# %%
node2strain = pickle.load(open(ds.static_path('nodes_inv.pickle')))

# %%
r.vertices.clear()
