# %%
import json, pickle
import numpy as np
import pandas as p

# %%
d = Dataset.objects.get(pk=19)

# %%
with open(d.static_path('nodes_inv.pickle')) as fp:
    nodes_inv = pickle.load(fp)

# %%
nodes_inv_inv = {}
for nid, sids in nodes_inv.iteritems():
    for sid in sids:
        nodes_inv_inv[sid] = nid

# %%
min(nodes_inv[5471])
# Out:
# 41731

# %%
for x in (796,297,2988,1680,6034,6074,607,1528,3562,950,537,5289,290,2511,4281,1749):
    print min(nodes_inv[x])
# Out:
# 42680
# 36502
# 37550
# 36841
# 35277
# 35968
# 39035
# 38879
# 37402
# 38590
# 39250
# 38229
# 36638
# 35692
# 35866
# 47634
