# %%
import pandas as p
import json

# %%
ds = Dataset.objects.get(pk=19)

# %%
nodes = json.load(open('/home/matej/dev/workspace/thecellmap/static/visualization/Living/nodes.json'))
layout = json.load(open('/home/matej/dev/workspace/thecellmap/static/visualization/Living/layout.json'))

# %%
node_map = {n['label'].lower(): n['id'] for n in nodes['nodes']}

# %%
df = p.read_table('/home/matej/todo/final_live_network/missing_nodes_coordinates_top5neighbors.txt')
df = df.dropna()

# %%
m = layout['nodes']
for l, x, y in df.itertuples(index=False):
    node_id = node_map[l]
    m.append({'id': node_id, 'x': x, 'y': y, 'c': 'green'})

# %%
len(layout['nodes'])
# Out:
# 6211

# %%
with open('/home/matej/dev/workspace/thecellmap/static/visualization/Living/layout_miss5.json', 'w') as fout:
    fout.write(json.dumps(layout).replace(' ', ''))
