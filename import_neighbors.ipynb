# %%
Gene.objects.all().update(neighbor_effect=False)
# Out:
# 7153

# %%
genemap = {g.orf: g.id for g in Gene.objects.all()}

# %%
neighbors = set()
with open('/home/matej/todo/thecellmap/neighbors_400bp.txt') as nei:
    for orf in nei:
        orf = orf.strip()
        neighbors.add(genemap[orf])

# %%
Gene.objects.filter(pk__in=neighbors).update(neighbor_effect=True)
# Out:
# 392
