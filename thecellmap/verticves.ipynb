# %%
r = Region.objects.get(pk=670)

# %%
for v in r.vertices.all():
    print(v.label())
# Out:
# RPS16B
# RPS1B
# RPL8A
# pol5-1
# tif6-ts4

# %%
v = Vertex.objects.get(strain__gene__name='RPL8A', region=670)

# %%
strain = Strain.objects.filter(gene__name='HBS1')

# %%
v.strain = strain[0]
v.save()
